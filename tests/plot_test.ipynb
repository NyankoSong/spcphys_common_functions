# %%
import sys
sys.path.append('../src')

import spcphys_common_functions as scf

# %%
import numpy as np
from matplotlib import pyplot as plt

fig, ax = plt.subplots()

quadmesh = scf.plot_tools.plot_hist2d(ax, np.random.randn(1000), np.random.randn(1000), np.random.randn(1000), color_norm_range=(-3, 3), hist_pcolormesh_args={'cmap':'RdBu'})
fig.colorbar(quadmesh)

# %%
fig, ax = plt.subplots()

quadmesh = scf.plot_tools.plot_hist2d(ax, np.random.randn(1000), np.random.randn(1000), hist_pcolormesh_args={'cmap':'RdBu_r'})
fig.colorbar(quadmesh)
