# %%
import sys
sys.path.append('/mnt/hc320/shares/mengsy/Documents/spcphys_common_functions/src')

import plot_tools
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 4
#       1 import sys
#       2 sys.path.append('/mnt/hc320/shares/mengsy/Documents/spcphys_common_functions/src')
# ----> 4 import plot_tools
#
# File ~/Documents/spcphys_common_functions/src/plot_tools.py:12
#       9 from scipy.signal import convolve2d
#      10 import scipy.stats as stats
# ---> 12 from . import config
#      13 from .utils import check_parameters
#      16 def _determine_bins(x, bins, scale):
#
# ImportError: attempted relative import with no known parent package

# %%
import numpy as np


plot_tools.plot_hist2d(np.random.randn(1000), np.random.randn(1000),
